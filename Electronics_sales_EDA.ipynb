# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Ramachandra M\Documents\Projects\Product Sales\electronics.csv")

# %%
df
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 0              0        0     5.0  1999-06-13     Female
# 1              0        1     5.0  1999-06-14     Female
# 2              0        2     3.0  1999-06-17     Female
# 3              0        3     1.0  1999-07-01     Female
# 4              0        4     2.0  1999-07-06     Female
# ...          ...      ...     ...         ...        ...
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
df.head(10)
# Out:
#    item_id  user_id  rating   timestamp model_attr                category  \
# 0        0        0     5.0  1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0  1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0  1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0  1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0  1999-07-06     Female  Portable Audio & Video
# 5        0        5     2.0  1999-07-12     Female  Portable Audio & Video
# 6        0        6     5.0  1999-07-13     Female  Portable Audio & Video
# 7        0        7     2.0  1999-07-13     Female  Portable Audio & Video
# 8        0        8     4.0  1999-07-16     Female  Portable Audio & Video
# 9        0        9     5.0  1999-08-20     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# ...

# %%
df.tail()
# Out:
#          item_id  user_id  rating   timestamp model_attr  \
# 1292949     9478  1157628     1.0  2018-09-26     Female
# 1292950     9435  1157629     5.0  2018-09-26     Female
# 1292951     9305  1157630     3.0  2018-09-26     Female
# 1292952     9303  1157631     5.0  2018-09-29       Male
# 1292953     9478  1157632     1.0  2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 1292949               Headphones  Etre Jeune  2017       NaN      0
# 1292950  Computers & Accessories         NaN  2017       NaN      0
# 1292951  Computers & Accessories         NaN  2016       NaN      0
# 1292952               Headphones         NaN  2018       NaN      0
# 1292953               Headphones  Etre Jeune  2017    Female      0

# %%
df.describe()
# Out:
#             item_id       user_id        rating          year         split
# count  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06  1.292954e+06
# mean   4.183588e+03  5.605127e+05  4.051482e+00  2.012938e+03  1.747587e-01
# std    2.525346e+03  3.342374e+05  1.379732e+00  2.643513e+00  5.506810e-01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.999000e+03  0.000000e+00
# 25%    2.018000e+03  2.697482e+05  4.000000e+00  2.012000e+03  0.000000e+00
# 50%    3.930000e+03  5.518920e+05  5.000000e+00  2.014000e+03  0.000000e+00
# 75%    6.289000e+03  8.474858e+05  5.000000e+00  2.015000e+03  0.000000e+00
# max    9.559000e+03  1.157632e+06  5.000000e+00  2.018000e+03  2.000000e+00

# %%
df.dtypes
# Out:
# item_id         int64
# user_id         int64
# rating        float64
# timestamp      object
# model_attr     object
# category       object
# brand          object
# year            int64
# user_attr      object
# split           int64
# dtype: object

# %%
import datetime

# %%
df["timestamp"]=pd.to_datetime(df["timestamp"])

# %%
df.dtypes
# Out:
# item_id                int64
# user_id                int64
# rating               float64
# timestamp     datetime64[ns]
# model_attr            object
# category              object
# brand                 object
# year                   int64
# user_attr             object
# split                  int64
# dtype: object

# %%
df.head()
# Out:
#    item_id  user_id  rating  timestamp model_attr                category  \
# 0        0        0     5.0 1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0 1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0 1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0 1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0 1999-07-06     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %%
df.brand.fillna(0)
# Out:
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
#               ...
# 1292949    Etre Jeune
# 1292950             0
# 1292951             0
# 1292952             0
# 1292953    Etre Jeune
# Name: brand, Length: 1292954, dtype: object

# %%
df.head()
# Out:
#    item_id  user_id  rating  timestamp model_attr                category  \
# 0        0        0     5.0 1999-06-13     Female  Portable Audio & Video
# 1        0        1     5.0 1999-06-14     Female  Portable Audio & Video
# 2        0        2     3.0 1999-06-17     Female  Portable Audio & Video
# 3        0        3     1.0 1999-07-01     Female  Portable Audio & Video
# 4        0        4     2.0 1999-07-06     Female  Portable Audio & Video
#
#   brand  year user_attr  split
# 0   NaN  1999       NaN      0
# 1   NaN  1999       NaN      0
# 2   NaN  1999       NaN      0
# 3   NaN  1999       NaN      0
# 4   NaN  1999       NaN      0

# %%
df.rename(columns={"model_attr":"Gender"})
# Out:
#          item_id  user_id  rating  timestamp  Gender                 category  \
# 0              0        0     5.0 1999-06-13  Female   Portable Audio & Video
# 1              0        1     5.0 1999-06-14  Female   Portable Audio & Video
# 2              0        2     3.0 1999-06-17  Female   Portable Audio & Video
# 3              0        3     1.0 1999-07-01  Female   Portable Audio & Video
# 4              0        4     2.0 1999-07-06  Female   Portable Audio & Video
# ...          ...      ...     ...        ...     ...                      ...
# 1292949     9478  1157628     1.0 2018-09-26  Female               Headphones
# 1292950     9435  1157629     5.0 2018-09-26  Female  Computers & Accessories
# 1292951     9305  1157630     3.0 2018-09-26  Female  Computers & Accessories
# 1292952     9303  1157631     5.0 2018-09-29    Male               Headphones
# 1292953     9478  1157632     1.0 2018-10-01  Female               Headphones
#
# ...

# %%
df.rename(columns={"Gender":"Model_Gender"})
# Out:
#          item_id  user_id  rating  timestamp model_attr  \
# 0              0        0     5.0 1999-06-13     Female
# 1              0        1     5.0 1999-06-14     Female
# 2              0        2     3.0 1999-06-17     Female
# 3              0        3     1.0 1999-07-01     Female
# 4              0        4     2.0 1999-07-06     Female
# ...          ...      ...     ...        ...        ...
# 1292949     9478  1157628     1.0 2018-09-26     Female
# 1292950     9435  1157629     5.0 2018-09-26     Female
# 1292951     9305  1157630     3.0 2018-09-26     Female
# 1292952     9303  1157631     5.0 2018-09-29       Male
# 1292953     9478  1157632     1.0 2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
df.columns
# Out:
# Index(['item_id', 'user_id', 'rating', 'timestamp', 'model_attr', 'category',
#        'brand', 'year', 'user_attr', 'split'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['item_id', 'user_id', 'rating', 'timestamp', 'model_attr', 'category',
#        'brand', 'year', 'user_attr', 'split'],
#       dtype='object')

# %%
df1=df.rename(columns={"model_attr":"Model_Gender"})

# %%
df1
# Out:
#          item_id  user_id  rating  timestamp Model_Gender  \
# 0              0        0     5.0 1999-06-13       Female
# 1              0        1     5.0 1999-06-14       Female
# 2              0        2     3.0 1999-06-17       Female
# 3              0        3     1.0 1999-07-01       Female
# 4              0        4     2.0 1999-07-06       Female
# ...          ...      ...     ...        ...          ...
# 1292949     9478  1157628     1.0 2018-09-26       Female
# 1292950     9435  1157629     5.0 2018-09-26       Female
# 1292951     9305  1157630     3.0 2018-09-26       Female
# 1292952     9303  1157631     5.0 2018-09-29         Male
# 1292953     9478  1157632     1.0 2018-10-01       Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
df1=df1.rename(columns={"user_attr":"User_Gender"})

# %%
df1.head()
# Out:
#    item_id  user_id  rating  timestamp Model_Gender                category  \
# 0        0        0     5.0 1999-06-13       Female  Portable Audio & Video
# 1        0        1     5.0 1999-06-14       Female  Portable Audio & Video
# 2        0        2     3.0 1999-06-17       Female  Portable Audio & Video
# 3        0        3     1.0 1999-07-01       Female  Portable Audio & Video
# 4        0        4     2.0 1999-07-06       Female  Portable Audio & Video
#
#   brand  year User_Gender  split
# 0   NaN  1999         NaN      0
# 1   NaN  1999         NaN      0
# 2   NaN  1999         NaN      0
# 3   NaN  1999         NaN      0
# 4   NaN  1999         NaN      0

# %%
import numpy as np

# %%
df.shape
# Out:
# (1292954, 10)

# %%
df1.shape
# Out:
# (1292954, 10)

# %%
df1.User_Gender.fillna(0)
# Out:
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
#             ...
# 1292949         0
# 1292950         0
# 1292951         0
# 1292952         0
# 1292953    Female
# Name: User_Gender, Length: 1292954, dtype: object

# %%
df1
# Out:
#          item_id  user_id  rating  timestamp Model_Gender  \
# 0              0        0     5.0 1999-06-13       Female
# 1              0        1     5.0 1999-06-14       Female
# 2              0        2     3.0 1999-06-17       Female
# 3              0        3     1.0 1999-07-01       Female
# 4              0        4     2.0 1999-07-06       Female
# ...          ...      ...     ...        ...          ...
# 1292949     9478  1157628     1.0 2018-09-26       Female
# 1292950     9435  1157629     5.0 2018-09-26       Female
# 1292951     9305  1157630     3.0 2018-09-26       Female
# 1292952     9303  1157631     5.0 2018-09-29         Male
# 1292953     9478  1157632     1.0 2018-10-01       Female
#
#                         category       brand  year User_Gender  split
# 0         Portable Audio & Video         NaN  1999         NaN      0
# 1         Portable Audio & Video         NaN  1999         NaN      0
# ...

# %%
df1
# Out:
#          item_id  user_id  rating  timestamp Model_Gender  \
# 0              0        0     5.0 1999-06-13       Female
# 1              0        1     5.0 1999-06-14       Female
# 2              0        2     3.0 1999-06-17       Female
# 3              0        3     1.0 1999-07-01       Female
# 4              0        4     2.0 1999-07-06       Female
# ...          ...      ...     ...        ...          ...
# 1292949     9478  1157628     1.0 2018-09-26       Female
# 1292950     9435  1157629     5.0 2018-09-26       Female
# 1292951     9305  1157630     3.0 2018-09-26       Female
# 1292952     9303  1157631     5.0 2018-09-29         Male
# 1292953     9478  1157632     1.0 2018-10-01       Female
#
#                         category       brand  year User_Gender  split
# 0         Portable Audio & Video         NaN  1999         NaN      0
# 1         Portable Audio & Video         NaN  1999         NaN      0
# ...

# %%
df.columns
# Out:
# Index(['item_id', 'user_id', 'rating', 'timestamp', 'model_attr', 'category',
#        'brand', 'year', 'user_attr', 'split'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# item_id                  int64
# user_id                  int64
# rating                 float64
# timestamp       datetime64[ns]
# Model_Gender            object
# category                object
# brand                   object
# year                     int64
# User_Gender             object
# split                    int64
# dtype: object

# %%
df1.shape
# Out:
# (1292954, 10)

# %%
df
# Out:
#          item_id  user_id  rating  timestamp model_attr  \
# 0              0        0     5.0 1999-06-13     Female
# 1              0        1     5.0 1999-06-14     Female
# 2              0        2     3.0 1999-06-17     Female
# 3              0        3     1.0 1999-07-01     Female
# 4              0        4     2.0 1999-07-06     Female
# ...          ...      ...     ...        ...        ...
# 1292949     9478  1157628     1.0 2018-09-26     Female
# 1292950     9435  1157629     5.0 2018-09-26     Female
# 1292951     9305  1157630     3.0 2018-09-26     Female
# 1292952     9303  1157631     5.0 2018-09-29       Male
# 1292953     9478  1157632     1.0 2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 0         Portable Audio & Video         NaN  1999       NaN      0
# 1         Portable Audio & Video         NaN  1999       NaN      0
# 2         Portable Audio & Video         NaN  1999       NaN      0
# ...

# %%
df1=df[df.year>2000]

# %%
df1
# Out:
#          item_id  user_id  rating  timestamp model_attr  \
# 78             3       78     4.0 2000-03-28     Female
# 79             3       79     5.0 2000-03-28     Female
# 80             3       80     4.0 2000-03-30     Female
# 81             3       81     5.0 2000-03-31     Female
# 84             3       84     1.0 2000-04-06     Female
# ...          ...      ...     ...        ...        ...
# 1292949     9478  1157628     1.0 2018-09-26     Female
# 1292950     9435  1157629     5.0 2018-09-26     Female
# 1292951     9305  1157630     3.0 2018-09-26     Female
# 1292952     9303  1157631     5.0 2018-09-29       Male
# 1292953     9478  1157632     1.0 2018-10-01     Female
#
#                         category       brand  year user_attr  split
# 78                Camera & Photo         NaN  2005       NaN      0
# 79                Camera & Photo         NaN  2005       NaN      0
# 80                Camera & Photo         NaN  2005       NaN      0
# ...

# %%
df1.sort_values("year")
# Out:
#          item_id  user_id  rating  timestamp   model_attr  \
# 1526          39     1482     5.0 2003-07-15       Female
# 136978         7   129880     1.0 2013-03-17       Female
# 773           44      759     5.0 2002-04-11       Female
# 774            7      760     5.0 2002-04-12       Female
# 775           34      761     4.0 2002-04-13       Female
# ...          ...      ...     ...        ...          ...
# 1249042      699  1118720     5.0 2018-03-24       Female
# 277103      4445   259460     5.0 2014-06-05         Male
# 1249043     9270  1118721     1.0 2018-03-24       Female
# 488201       379   448693     5.0 2015-04-19  Female&Male
# 1095177      303   982921     5.0 2017-04-18         Male
#
#                         category    brand  year user_attr  split
# 1526              Camera & Photo     Sony  2001       NaN      0
# 136978                Home Audio  Philips  2001       NaN      0
# 773      Computers & Accessories  Toshiba  2001       NaN      0
# ...
